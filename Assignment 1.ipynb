# %% [markdown]
# # Operation on Iris Dataset

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

## visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## 1. Reading the Datasets

# %%
df = pd.read_excel('iris.xls')

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 2. Disply the columns in the dataset

# %%
df.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ## 3. Mean value of each column in the dataset

# %%
df.mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4152\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4. Check the null values present in the dataset

# %%
df.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()   ## no column has missing values
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ## 5. Data Visualization

# %% [markdown]
# ### 1) Univariate analysis of categorical variables

# %%
# count plot of column = 'classification'

sns.countplot(x='Classification', data = df)
# Out:
# <Axes: xlabel='Classification', ylabel='count'>

# %%
# catplot of column = 'classification'

sns.catplot(x='Classification', data = df)

# %% [markdown]
# ### 2) univariate analysis of numerical columns

# %%
# distplot of SL

sns.distplot(df.SL,bins=30, color='g')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4152\1833285150.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.SL,bins=30, color='g')
# <Axes: xlabel='SL', ylabel='Density'>

# %% [markdown]
# ### 3) Bivariate Analysis: numerical vs Numerical

# %%
#lineplot 
# SL and SW

sns.lineplot(x='SL',y='SW', data=df)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
#lineplot 
# PL and PW

sns.lineplot(x='PL',y='PW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %%
#Boxplot of SW

sns.boxplot(x='SW',data=df)
# Out:
# <Axes: xlabel='SW'>

# %%
# scatter plot of PL vs PW

sns.scatterplot(x='PL',y='PW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %%
# scatter plot of SL vs SW

sns.scatterplot(x='SL',y='SW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %% [markdown]
# ### 4) Bi-variate analysis - numerical vs categorical

# %%
sns.barplot(x='SL',y='Classification',data=df)
# Out:
# <Axes: xlabel='SL', ylabel='Classification'>

# %%
# point plot of SW and Classification
sns.pointplot(x='SW',y='Classification',data=df)
# Out:
# <Axes: xlabel='SW', ylabel='Classification'>

# %% [markdown]
# ### 5) Multivariate Analysis

# %%
# Heatmap
sns.heatmap(data=df.corr(),annot=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4152\1599800381.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True)
# <Axes: >
